# %%
import pandas as pd
import numpy as np

df = pd.read_csv("population_vi_v2.csv")
df
# Out:
#     Các tỉnh thành  Mật độ dân số  Dân số trung bình  Tỷ lệ giới tính  \
# 0           Hà Nội         2031.1             6761.3            97.80
# 1        Vĩnh Phúc          818.0             1011.4            97.60
# 2         Bắc Ninh         1292.6             1063.4            96.70
# 3       Quảng Ninh          191.4             1168.0           105.40
# 4        Hải Dương         1044.6             1729.8            96.10
# ..             ...            ...                ...              ...
# 625        Cần Thơ          862.0             1240.7            98.65
# 626      Hậu Giang          450.0              729.8           101.38
# 627      Sóc Trăng          361.0             1195.7            99.34
# 628       Bạc Liêu          342.0              913.5           100.15
# 629         Cà Mau          229.0             1193.9           102.64
#
#      Tỷ lệ gia tăng dân số  Lực lương lao động từ 15 tuổi trở lên  \
# 0                     1.93                                3572.90
# 1                     0.38                                 608.30
# 2                     1.84                                 593.50
# 3                     0.93                                 675.00
# 4                     0.78                                1071.00
# ..                     ...                                    ...
# 625                   0.39                                 716.78
# 626                  -0.33                                 402.33
# 627                  -0.32                                 641.91
# 628                   0.58                                 507.76
# 629                  -0.03                                 669.77
#
#                         Vùng   Năm
# 0        Đồng bằng sông Hồng  2011
# 1        Đồng bằng sông Hồng  2011
# 2        Đồng bằng sông Hồng  2011
# 3        Đồng bằng sông Hồng  2011
# 4        Đồng bằng sông Hồng  2011
# ..                       ...   ...
# 625  Đồng bằng sông Cửu Long  2020
# 626  Đồng bằng sông Cửu Long  2020
# 627  Đồng bằng sông Cửu Long  2020
# 628  Đồng bằng sông Cửu Long  2020
# 629  Đồng bằng sông Cửu Long  2020
#
# [630 rows x 8 columns]

# %%
#Lọc các bản ghi được ghi chép vào 2,3 năm trước.
df[((df['Năm'] == 2020)|(df['Năm'] == 2019))]
# Out:
#     Các tỉnh thành  Mật độ dân số  Dân số trung bình  Tỷ lệ giới tính  \
# 504         Hà Nội         2410.0             8093.9            98.32
# 505      Vĩnh Phúc          934.0             1154.8            99.32
# 506       Bắc Ninh         1676.0             1378.6            97.62
# 507     Quảng Ninh          214.0             1324.8           103.48
# 508      Hải Dương         1137.0             1896.9            98.80
# ..             ...            ...                ...              ...
# 625        Cần Thơ          862.0             1240.7            98.65
# 626      Hậu Giang          450.0              729.8           101.38
# 627      Sóc Trăng          361.0             1195.7            99.34
# 628       Bạc Liêu          342.0              913.5           100.15
# 629         Cà Mau          229.0             1193.9           102.64
#
#      Tỷ lệ gia tăng dân số  Lực lương lao động từ 15 tuổi trở lên  \
# 504                   2.27                                4118.30
# 505                   1.45                                 647.40
# 506                   3.08                                 777.70
# 507                   1.61                                 734.50
# 508                   1.02                                1070.80
# ..                     ...                                    ...
# 625                   0.39                                 716.78
# 626                  -0.33                                 402.33
# 627                  -0.32                                 641.91
# 628                   0.58                                 507.76
# 629                  -0.03                                 669.77
#
#                         Vùng   Năm
# 504      Đồng bằng sông Hồng  2019
# 505      Đồng bằng sông Hồng  2019
# 506      Đồng bằng sông Hồng  2019
# 507      Đồng bằng sông Hồng  2019
# 508      Đồng bằng sông Hồng  2019
# ..                       ...   ...
# 625  Đồng bằng sông Cửu Long  2020
# 626  Đồng bằng sông Cửu Long  2020
# 627  Đồng bằng sông Cửu Long  2020
# 628  Đồng bằng sông Cửu Long  2020
# 629  Đồng bằng sông Cửu Long  2020
#
# [126 rows x 8 columns]

# %%
#Lọc các bản ghi ở vùng Đồng bằng sông Cửu Long hoặc Đồng bằng sông Hồng có Lực lương lao động từ 15 tuổi trở lên > 2000 và Mật độ dân số >1500
df[((df["Vùng"] == "Đồng bằng sông Hồng") | (df["Vùng"] == "Đồng bằng sông Cửu Long")) & (df["Lực lương lao động từ 15 tuổi trở lên"]>2000) & (df["Mật độ dân số"]>1500)].reset_index()
# Out:
#    index Các tỉnh thành  Mật độ dân số  Dân số trung bình  Tỷ lệ giới tính  \
# 0      0         Hà Nội         2031.1             6761.3            97.80
# 1     63         Hà Nội         2065.6             6865.2            95.40
# 2    126         Hà Nội         2098.8             6977.0            96.40
# 3    189         Hà Nội         2134.0             7095.9            95.00
# 4    252         Hà Nội         2171.0             7216.0            95.60
# 5    315         Hà Nội         2182.0             7328.4            96.20
# 6    378         Hà Nội         2209.0             7420.1            98.00
# 7    441         Hà Nội         2239.0             7520.7            98.10
# 8    504         Hà Nội         2410.0             8093.9            98.32
# 9    567         Hà Nội         2455.0             8246.6            98.09
#
#    Tỷ lệ gia tăng dân số  Lực lương lao động từ 15 tuổi trở lên  \
# 0                   1.93                                3572.90
# 1                   1.54                                3702.50
# 2                   1.63                                3799.60
# 3                   1.70                                3832.40
# 4                   1.51                                3820.90
# 5                   1.50                                3822.50
# 6                   1.99                                4024.20
# 7                   2.23                                4064.80
# 8                   2.27                                4118.30
# 9                   1.89                                4124.62
#
#                   Vùng   Năm
# 0  Đồng bằng sông Hồng  2011
# 1  Đồng bằng sông Hồng  2012
# 2  Đồng bằng sông Hồng  2013
# 3  Đồng bằng sông Hồng  2014
# 4  Đồng bằng sông Hồng  2015
# 5  Đồng bằng sông Hồng  2016
# 6  Đồng bằng sông Hồng  2017
# 7  Đồng bằng sông Hồng  2018
# 8  Đồng bằng sông Hồng  2019
# 9  Đồng bằng sông Hồng  2020

# %%
#Lọc ra các bản ghi có mật độ dân số lớn hơn 1800 và tỉ lệ gia tăng dân số lớn hơn 1.7. Chỉ lấy cột từ 0 đến 4 lưu thành df1
#df1 = df.iloc[:,0:4][(df["Mật độ dân số"]>1800) & (df["Tỷ lệ gia tăng dân số"]>1.7)].reset_index(drop=False)
#df1
#df1 = df[(df["Mật độ dân số"]>1800) & (df["Tỷ lệ gia tăng dân số"]>1.7)][["Các tỉnh thành","Mật độ dân số", "Dân số trung bình","Tỷ lệ giới tính", "Tỷ lệ gia tăng dân số"]]
df1 = df[(df["Mật độ dân số"]>1800) & (df["Tỷ lệ gia tăng dân số"]>1.7)]
df1.drop(["Lực lương lao động từ 15 tuổi trở lên","Vùng","Năm"],axis = 1)
df1.reset_index()
# Out:
#     index Các tỉnh thành  Mật độ dân số  Dân số trung bình  Tỷ lệ giới tính  \
# 0       0         Hà Nội         2031.1             6761.3            97.80
# 1      49    Hồ Chí Minh         3578.2             7498.4            91.10
# 2     112    Hồ Chí Minh         3655.4             7660.3            93.10
# 3     175    Hồ Chí Minh         3731.6             7820.0            93.20
# 4     238    Hồ Chí Minh         3809.0             7981.9            92.20
# 5     301    Hồ Chí Minh         3888.0             8146.3            91.80
# 6     364    Hồ Chí Minh         4025.0             8297.5            91.90
# 7     378         Hà Nội         2209.0             7420.1            98.00
# 8     427    Hồ Chí Minh         4097.0             8444.6            94.50
# 9     441         Hà Nội         2239.0             7520.7            98.10
# 10    490    Hồ Chí Minh         4171.0             8598.7            94.80
# 11    504         Hà Nội         2410.0             8093.9            98.32
# 12    553    Hồ Chí Minh         4385.0             9038.6            95.07
# 13    567         Hà Nội         2455.0             8246.6            98.09
# 14    616    Hồ Chí Minh         4476.0             9227.6            94.93
#
#     Tỷ lệ gia tăng dân số  Lực lương lao động từ 15 tuổi trở lên  \
# 0                    1.93                                3572.90
# 1                    2.07                                4000.90
# 2                    2.16                                4086.40
# 3                    2.08                                4122.30
# 4                    2.07                                4188.50
# 5                    1.83                                4251.40
# 6                    1.96                                4335.70
# 7                    1.99                                4024.20
# 8                    2.01                                4578.70
# 9                    2.23                                4064.80
# 10                   2.24                                4684.90
# 11                   2.27                                4118.30
# 12                   2.21                                4826.00
# 13                   1.89                                4124.62
# 14                   2.09                                4769.63
#
#                    Vùng   Năm
# 0   Đồng bằng sông Hồng  2011
# 1           Đông Nam Bộ  2011
# 2           Đông Nam Bộ  2012
# 3           Đông Nam Bộ  2013
# 4           Đông Nam Bộ  2014
# 5           Đông Nam Bộ  2015
# 6           Đông Nam Bộ  2016
# 7   Đồng bằng sông Hồng  2017
# 8           Đông Nam Bộ  2017
# 9   Đồng bằng sông Hồng  2018
# 10          Đông Nam Bộ  2018
# 11  Đồng bằng sông Hồng  2019
# 12          Đông Nam Bộ  2019
# 13  Đồng bằng sông Hồng  2020
# 14          Đông Nam Bộ  2020

# %%
#Lọc ra 10 bản ghi có số lượng lực lượng lao động cao nhất. Chỉ lấy cột tỉnh thành lực lượng lao động từ 15 tuổi trở lên và vùng, năm. Lưu thành df2
#Merge dataframe 1 và 2 với nhau tạo thành df3 có số index chuẩn.
#Sort_values: chúng ta cần lấy 10 bản ghi có lực lượng lao động trên 15 tuổi cao nhất
df2 = df[["Các tỉnh thành", "Lực lương lao động từ 15 tuổi trở lên","Vùng","Năm"]].sort_values( "Lực lương lao động từ 15 tuổi trở lên",ascending = False)[0:10]
df3 = pd.concat([df1,df2],axis = 0)
df3.reset_index(inplace = True)
df3.drop("index", axis = 1, inplace = True)
df3
# Out:
#    Các tỉnh thành  Mật độ dân số  Dân số trung bình  Tỷ lệ giới tính  \
# 0          Hà Nội         2031.1             6761.3            97.80
# 1     Hồ Chí Minh         3578.2             7498.4            91.10
# 2     Hồ Chí Minh         3655.4             7660.3            93.10
# 3     Hồ Chí Minh         3731.6             7820.0            93.20
# 4     Hồ Chí Minh         3809.0             7981.9            92.20
# 5     Hồ Chí Minh         3888.0             8146.3            91.80
# 6     Hồ Chí Minh         4025.0             8297.5            91.90
# 7          Hà Nội         2209.0             7420.1            98.00
# 8     Hồ Chí Minh         4097.0             8444.6            94.50
# 9          Hà Nội         2239.0             7520.7            98.10
# 10    Hồ Chí Minh         4171.0             8598.7            94.80
# 11         Hà Nội         2410.0             8093.9            98.32
# 12    Hồ Chí Minh         4385.0             9038.6            95.07
# 13         Hà Nội         2455.0             8246.6            98.09
# 14    Hồ Chí Minh         4476.0             9227.6            94.93
# 15    Hồ Chí Minh            NaN                NaN              NaN
# 16    Hồ Chí Minh            NaN                NaN              NaN
# 17    Hồ Chí Minh            NaN                NaN              NaN
# 18    Hồ Chí Minh            NaN                NaN              NaN
# 19    Hồ Chí Minh            NaN                NaN              NaN
# 20    Hồ Chí Minh            NaN                NaN              NaN
# 21    Hồ Chí Minh            NaN                NaN              NaN
# 22         Hà Nội            NaN                NaN              NaN
# 23    Hồ Chí Minh            NaN                NaN              NaN
# 24         Hà Nội            NaN                NaN              NaN
#
#     Tỷ lệ gia tăng dân số  Lực lương lao động từ 15 tuổi trở lên  \
# 0                    1.93                                3572.90
# 1                    2.07                                4000.90
# 2                    2.16                                4086.40
# 3                    2.08                                4122.30
# 4                    2.07                                4188.50
# 5                    1.83                                4251.40
# 6                    1.96                                4335.70
# 7                    1.99                                4024.20
# 8                    2.01                                4578.70
# 9                    2.23                                4064.80
# 10                   2.24                                4684.90
# 11                   2.27                                4118.30
# 12                   2.21                                4826.00
# 13                   1.89                                4124.62
# 14                   2.09                                4769.63
# 15                    NaN                                4826.00
# 16                    NaN                                4769.63
# 17                    NaN                                4684.90
# 18                    NaN                                4578.70
# 19                    NaN                                4335.70
# 20                    NaN                                4251.40
# 21                    NaN                                4188.50
# 22                    NaN                                4124.62
# 23                    NaN                                4122.30
# 24                    NaN                                4118.30
#
#                    Vùng   Năm
# 0   Đồng bằng sông Hồng  2011
# 1           Đông Nam Bộ  2011
# 2           Đông Nam Bộ  2012
# 3           Đông Nam Bộ  2013
# 4           Đông Nam Bộ  2014
# 5           Đông Nam Bộ  2015
# 6           Đông Nam Bộ  2016
# 7   Đồng bằng sông Hồng  2017
# 8           Đông Nam Bộ  2017
# 9   Đồng bằng sông Hồng  2018
# 10          Đông Nam Bộ  2018
# 11  Đồng bằng sông Hồng  2019
# 12          Đông Nam Bộ  2019
# 13  Đồng bằng sông Hồng  2020
# 14          Đông Nam Bộ  2020
# 15          Đông Nam Bộ  2019
# 16          Đông Nam Bộ  2020
# 17          Đông Nam Bộ  2018
# 18          Đông Nam Bộ  2017
# 19          Đông Nam Bộ  2016
# 20          Đông Nam Bộ  2015
# 21          Đông Nam Bộ  2014
# 22  Đồng bằng sông Hồng  2020
# 23          Đông Nam Bộ  2013
# 24  Đồng bằng sông Hồng  2019

# %%
#Với mỗi vùng, tính trung bình mật độ dân số, tỷ lệ giới tính, tỉ lệ gia tăng dân số và tổng lực lượng lao động từ 15 tuổi trở lên. 
#Trả về df4, lưu tên các cột tương ứng toán tử được sử dụng.
df4 = pd.pivot_table(df,index = "Vùng", values = {"Mật độ dân số","Tỷ lệ giới tính", "Tỷ lệ gia tăng dân số", "Lực lương lao động từ 15 tuổi trở lên"}, aggfunc = {"Mật độ dân số":"mean", "Tỷ lệ gia tăng dân số":"mean", "Lực lương lao động từ 15 tuổi trở lên":"sum"})
df4.rename( columns = {"Lực lương lao động từ 15 tuổi trở lên":"Tổng LLLD 15+","Mật độ dân số":"Avg Mật độ dân số","Tỷ lệ gia tăng dân số":"Avg Tỷ lệ gia tăng dân số"}, inplace = True)
df4.reset_index(inplace = True)
df4
# Out:
#                                    Vùng  Tổng LLLD 15+  Avg Mật độ dân số  \
# 0  Bắc Trung bộ và duyên hải miền Trung      116420.48         239.439286
# 1         Trung du và miền núi phía Bắc       74800.15         159.247143
# 2                            Tây Nguyên       33373.08         101.162000
# 3                           Đông Nam Bộ       92343.75        1032.426667
# 4               Đồng bằng sông Cửu Long      102545.91         489.060769
# 5                   Đồng bằng sông Hồng      120504.09        1111.703636
#
#    Avg Tỷ lệ gia tăng dân số
# 0                   0.689429
# 1                   1.252429
# 2                   1.669400
# 3                   1.948167
# 4                   0.268385
# 5                   0.995636
