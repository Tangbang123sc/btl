# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('LandTrading.csv')
df
# Out:
#        Unnamed: 0  dien_tich huong_ban_cong  phong_ngu  \
# 0               0      220.0            NaN        1.0
# 1               1      500.0            NaN        NaN
# 2               2      154.0            NaN        1.0
# 3               3      116.0            NaN        NaN
# 4               4      195.0            NaN        1.0
# ...           ...        ...            ...        ...
# 27249       27249       72.0            NaN        NaN
# 27250       27250       90.0            NaN        NaN
# 27251       27251      100.0            NaN        NaN
# 27252       27252      100.0            NaN        NaN
# 27253       27253       90.0            NaN        NaN
#
#                    id_thanh_pho     ten_thanh_pho                   id_quan  \
# 0      5e5501caeb80a7245175dddb  Thành phố Hà Nội  5e5501caeb80a7245175de1a
# 1      5e5501caeb80a7245175dddb  Thành phố Hà Nội  5e5501caeb80a7245175de1a
# 2      5e5501caeb80a7245175dddb  Thành phố Hà Nội  5e5501caeb80a7245175de1a
# 3      5e5501caeb80a7245175dddb  Thành phố Hà Nội  5e5501caeb80a7245175de1a
# 4      5e5501caeb80a7245175dddb  Thành phố Hà Nội  5e5501caeb80a7245175de1a
# ...                         ...               ...                       ...
# 27249  5e5501caeb80a7245175dddb  Thành phố Hà Nội  5e5501caeb80a7245175dedd
# 27250  5e5501caeb80a7245175dddb  Thành phố Hà Nội  5e5501caeb80a7245175dedd
# 27251  5e5501caeb80a7245175dddb  Thành phố Hà Nội  5e5501caeb80a7245175dedd
# 27252  5e5501caeb80a7245175dddb  Thành phố Hà Nội  5e5501caeb80a7245175dedd
# 27253  5e5501caeb80a7245175dddb  Thành phố Hà Nội  5e5501caeb80a7245175dedd
#
#               ten_quan  so_tang  mat_tien  ...       gia      gia_m2 du_an  \
# 0         Quận Ba Đình      1.0       NaN  ...   30000.0  136.363636   NaN
# 1         Quận Ba Đình      NaN       NaN  ...  195000.0  390.000000   NaN
# 2         Quận Ba Đình      1.0       NaN  ...   40000.0  259.740260   NaN
# 3         Quận Ba Đình      NaN       NaN  ...   14300.0  123.275862   NaN
# 4         Quận Ba Đình      1.0       NaN  ...   26500.0  135.897436   NaN
# ...                ...      ...       ...  ...       ...         ...   ...
# 27249  Huyện Phú Xuyên      NaN       NaN  ...     670.0    9.305556   NaN
# 27250  Huyện Phú Xuyên      NaN       NaN  ...     800.0    8.888889   NaN
# 27251  Huyện Phú Xuyên      NaN       8.0  ...       NaN         NaN   NaN
# 27252  Huyện Phú Xuyên      NaN       NaN  ...       NaN         NaN   NaN
# 27253  Huyện Phú Xuyên      NaN       NaN  ...    2150.0   23.888889   NaN
#
#        project_name                  id_duong             ten_duong  \
# 0               NaN  5e958ee8208d0d6d7648f9cc         Phố Linh Lang
# 1               NaN  5e958ee8208d0d6d7648f96d     Đường Cao Bá Quát
# 2               NaN  5e958ee8208d0d6d7648f978         Đường Đội Cấn
# 3               NaN  5e958ee8208d0d6d7648f974         Đường Đào Tấn
# 4               NaN  5e958ee8208d0d6d7648f97a  Đường Giang Văn Minh
# ...             ...                       ...                   ...
# 27249           NaN                       NaN                   NaN
# 27250           NaN  5e958eef208d0d6d76490f18      Đường Quốc lộ 1A
# 27251           NaN  5e958eef208d0d6d76490f1c     Đường Tỉnh lộ 428
# 27252           NaN                       NaN                   NaN
# 27253           NaN  5e958eef208d0d6d76490f18      Đường Quốc lộ 1A
#
#        do_rong_duong    do_rong_duong_ml                 id_phuong  \
# 0               10.0    Ngõ 4 ô tô tránh  5e5501cbeb80a7245175e0e4
# 1               40.0  Ngõ 4 ô tô trở lên  5e5501cbeb80a7245175e0e9
# 2               20.0  Ngõ 4 ô tô trở lên  5e5501cbeb80a7245175e0ea
# 3                8.0    Ngõ 3 ô tô tránh  5e5501cbeb80a7245175e0e4
# 4              100.0  Ngõ 4 ô tô trở lên  5e5501cbeb80a7245175e0ec
# ...              ...                 ...                       ...
# 27249            NaN                 NaN  5e5501cceb80a7245175e2e5
# 27250            NaN                 NaN  5e5501cceb80a7245175e2e4
# 27251            NaN                 NaN  5e5501cceb80a7245175e2ed
# 27252            NaN                 NaN  5e5501cceb80a7245175e2db
# 27253            NaN                 NaN  5e5501cceb80a7245175e2f0
#
#                ten_phuong
# 0          Phường Cống Vị
# 1        Phường Điện Biên
# 2          Phường Đội Cấn
# 3          Phường Cống Vị
# 4           Phường Kim Mã
# ...                   ...
# 27249       Xã Hoàng Long
# 27250        Xã Hồng Thái
# 27251        Xã Phúc Tiến
# 27252  Thị trấn Phú Xuyên
# 27253        Xã Đại Xuyên
#
# [27254 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27254 entries, 0 to 27253
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        27254 non-null  int64
#  1   dien_tich         26962 non-null  float64
#  2   huong_ban_cong    102 non-null    object
#  3   phong_ngu         1077 non-null   float64
#  4   id_thanh_pho      27254 non-null  object
#  5   ten_thanh_pho     27254 non-null  object
#  6   id_quan           27254 non-null  object
#  7   ten_quan          27254 non-null  object
#  8   so_tang           1283 non-null   float64
#  9   mat_tien          13055 non-null  float64
#  10  noi_that          166 non-null    object
#  11  huong_nha         8611 non-null   object
#  12  so_do             14688 non-null  object
#  13  lat               27223 non-null  float64
#  14  long              27223 non-null  float64
#  15  gia               22967 non-null  float64
#  16  gia_m2            22979 non-null  float64
#  17  du_an             23 non-null     object
#  18  project_name      23 non-null     object
#  19  id_duong          21754 non-null  object
#  20  ten_duong         21754 non-null  object
#  21  do_rong_duong     3468 non-null   float64
#  22  do_rong_duong_ml  4002 non-null   object
#  23  id_phuong         24172 non-null  object
#  24  ten_phuong        24172 non-null  object
# dtypes: float64(9), int64(1), object(15)
# memory usage: 5.2+ MB

# %%
df_merge = pd.DataFrame()
# from scratch 
target = df[df["id_quan"]=="5e5501caeb80a7245175de1a"].reset_index(drop=True)
# group theo duong 
df_group = target.groupby("id_duong")


for street_name, street_df in df_group:
    mean =  street_df["do_rong_duong"].mean()
    if not pd.isna(mean):
        # tim tat ca nhung row ma bi khuyet thieu cai gia tri do rong duong
        mask = street_df["do_rong_duong"].isna()
        street_df[mask]["do_rong_duong"] = mean
        df_merge = pd.concat([df_merge, street_df], axis=0)
    # break
print(len(target["do_rong_duong"].isna().index))
print("*"*30)
print(len(df_merge["do_rong_duong"].isna().index))
# Out:
# 274
# ******************************
# 155
# C:\Users\TANPHA~1\AppData\Local\Temp/ipykernel_16684/229268831.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   street_df[mask]["do_rong_duong"] = mean

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27254 entries, 0 to 27253
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        27254 non-null  int64
#  1   dien_tich         26962 non-null  float64
#  2   huong_ban_cong    102 non-null    object
#  3   phong_ngu         1077 non-null   float64
#  4   id_thanh_pho      27254 non-null  object
#  5   ten_thanh_pho     27254 non-null  object
#  6   id_quan           27254 non-null  object
#  7   ten_quan          27254 non-null  object
#  8   so_tang           1283 non-null   float64
#  9   mat_tien          13055 non-null  float64
#  10  noi_that          166 non-null    object
#  11  huong_nha         8611 non-null   object
#  12  so_do             14688 non-null  object
#  13  lat               27223 non-null  float64
#  14  long              27223 non-null  float64
#  15  gia               22967 non-null  float64
#  16  gia_m2            22979 non-null  float64
#  17  du_an             23 non-null     object
#  18  project_name      23 non-null     object
#  19  id_duong          21754 non-null  object
#  20  ten_duong         21754 non-null  object
#  21  do_rong_duong     3468 non-null   float64
#  22  do_rong_duong_ml  4002 non-null   object
#  23  id_phuong         24172 non-null  object
#  24  ten_phuong        24172 non-null  object
# dtypes: float64(9), int64(1), object(15)
# memory usage: 5.2+ MB
